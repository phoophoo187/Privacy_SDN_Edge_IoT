# %%
from Cls_topology import Cls_topology
from OptPrunRoute import OptPrunRoute

# %%
topo= Cls_topology()

# %%
testnet = topo.create_g_from_json("./ExpNetwork2.json")

# %%
topo.draw_graph(testnet)

# %%
routeObj = OptPrunRoute()

# %%
G=testnet.copy()

# %%
Opt_path=routeObj.Optimum_prun_based_routing(G,'S','D',5,1)

# %%
print(Opt_path)
# Out:
# ['S', 'B', 'D']

# %%
topo.draw_graph(G)

# %%
testnet = topo.create_g_from_json("./ExpNetwork2.json")

# %%
topo.draw_graph(testnet)

# %%
H = testnet.copy()

# %%
topo.draw_graph(H)

# %%
Opt_path=routeObj.Optimum_prun_based_routing(H,'E3','G1',15,1)

# %%
print(Opt_path)
# Out:
# ['E3', 'G1']

# %%
pos = {'G1': (50, 100), 'E1': (0, 50), 'E2': (50, 50), 'E3': (100,50), 'E4': (0, 0), 'E5': (50, 0), 'E6': (100, 0)}

# %%
topo.draw_graph(H)

# %%
topo.draw_graph_pos(H,pos)
